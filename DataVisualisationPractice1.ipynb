# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
np.random.seed(20)
df = pd.DataFrame(np.random.rand(1000,1), index=pd.date_range('2021-07-18', periods=1000), columns=['data'])

# %%
df
# Out:
#                 data
# 2021-07-18  0.588131
# 2021-07-19  0.897714
# 2021-07-20  0.891531
# 2021-07-21  0.815837
# 2021-07-22  0.035890
# ...              ...
# 2024-04-08  0.992189
# 2024-04-09  0.756037
# 2024-04-10  0.299186
# 2024-04-11  0.261712
# 2024-04-12  0.968979
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.data.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
df['data1'] = df.data.cumsum()

# %%
df['data2'] = df['data'].apply(lambda x: x*3)

# %%
df
# Out:
#                 data       data1     data2
# 2021-07-18  0.588131    0.588131  1.764392
# 2021-07-19  0.897714    1.485845  2.693141
# 2021-07-20  0.891531    2.377375  2.674592
# 2021-07-21  0.815837    3.193213  2.447512
# 2021-07-22  0.035890    3.229102  0.107669
# ...              ...         ...       ...
# 2024-04-08  0.992189  495.812936  2.976566
# 2024-04-09  0.756037  496.568973  2.268112
# 2024-04-10  0.299186  496.868159  0.897559
# 2024-04-11  0.261712  497.129872  0.785137
# 2024-04-12  0.968979  498.098851  2.906937
#
# [1000 rows x 3 columns]

# %%
df.plot(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
df1 = sns.load_dataset('iris')

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot(figsize=(5,5), title='irish data')
# Out:
# <AxesSubplot:title={'center':'irish data'}>

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
gf = df1.plot(figsize=(5,5), title='irish data')
gf.set_xlabel("This is x axis")
gf.set_ylabel("This is y axis")
# Out:
# Text(0, 0.5, 'This is y axis')

# %%
df1.iloc[0][0:4]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
df1.iloc[0][0:4].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df2 = sns.load_dataset('titanic')

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2['pclass'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df3 = pd.DataFrame(np.random.rand(10,4), columns=['a','b','c','d'])

# %%
df3
# Out:
#           a         b         c         d
# 0  0.534850  0.141536  0.997549  0.663146
# 1  0.310007  0.127744  0.547494  0.029529
# 2  0.344711  0.929877  0.579118  0.643341
# 3  0.557322  0.307009  0.887460  0.760641
# 4  0.249756  0.648684  0.123295  0.508399
# 5  0.174770  0.759351  0.493705  0.254648
# 6  0.393292  0.008692  0.296240  0.232336
# 7  0.841515  0.442961  0.656447  0.080341
# 8  0.719348  0.575515  0.577130  0.251678
# 9  0.166954  0.675000  0.177515  0.724717

# %%
df3.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df3.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['sepal_length'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot(kind='hist', stacked=True, bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot(kind='hist', stacked=True, bins=100, orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df1.hist()
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df1.plot.scatter(x='sepal_width', y='petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df1.plot.scatter(x='sepal_width', y='petal_width', c='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df1.plot.scatter(x='sepal_length', y='sepal_width', label='iris', s=80, c='petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df1.plot.hexbin(x='sepal_length', y='sepal_width', label='iris', gridsize=10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df
# Out:
#                 data       data1     data2
# 2021-07-18  0.588131    0.588131  1.764392
# 2021-07-19  0.897714    1.485845  2.693141
# 2021-07-20  0.891531    2.377375  2.674592
# 2021-07-21  0.815837    3.193213  2.447512
# 2021-07-22  0.035890    3.229102  0.107669
# ...              ...         ...       ...
# 2024-04-08  0.992189  495.812936  2.976566
# 2024-04-09  0.756037  496.568973  2.268112
# 2024-04-10  0.299186  496.868159  0.897559
# 2024-04-11  0.261712  497.129872  0.785137
# 2024-04-12  0.968979  498.098851  2.906937
#
# [1000 rows x 3 columns]

# %%
d = df.iloc[0]

# %%
d
# Out:
# data     0.588131
# data1    0.588131
# data2    1.764392
# Name: 2021-07-18 00:00:00, dtype: float64

# %%
d.plot.pie()
# Out:
# <AxesSubplot:ylabel='2021-07-18 00:00:00'>

# %%
df1.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
iris = df1.head(3).T

# %%
iris
# Out:
#                    0       1       2
# sepal_length     5.1     4.9     4.7
# sepal_width      3.5     3.0     3.2
# petal_length     1.4     1.4     1.3
# petal_width      0.2     0.2     0.2
# species       setosa  setosa  setosa

# %%
iris.iloc[0:4].plot.pie(subplots=True, figsize=(20,20), fontsize=20, autopct='%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pd.plotting.scatter_matrix(df1)
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
pd.plotting.scatter_matrix(df1, diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
df['data'].plot(style='r--', legend=True, label='kesh')
# Out:
# <AxesSubplot:>

# %%
df['data'].plot(style='r*', legend=True, label='kesh')
# Out:
# <AxesSubplot:>

# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)'))': /packages/5f/43/6e86a1e1910d434f068a8e032a3cc77ce862f1688776793a6735e5712fd9/plotly-5.10.0-py2.py3-none-any.whl
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68734 sha256=4d3165d9d62aae25f25d715bf0ee87220917c83fe5d3a6beca95eba0b0322460
#   Stored in directory: c:\users\kesdan02\appdata\local\pip\cache\wheels\29\b4\f8\2fd2206eeeba6ccad8167e4e8894b8c4ec27bf1342037fd136
# Successfully built cufflinks
# ...

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf

# %%
py.__version__
# Out:
# '5.10.0'

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df1.iplot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\cufflinks\plotlytools.py in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1430                 try:
# -> 1431                         import chart_studio.plotly as py
#    1432                 except:
#
# ModuleNotFoundError: No module named 'chart_studio'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10164/3443576117.py in <module>
# ----> 1 df1.iplot()
#
# ...

# %%
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
df1.iplot()
# Out:
# <div>                            <div id="053da54f-6493-4013-b3db-ad524aaebaa9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2.iplot(kind='scatter', x='fare', y='age', mode='markers', xTitle='fare', yTitle='age')
# Out:
# <div>                            <div id="fdf20924-6954-4058-808f-99b98668105f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.getTheme()
# Out:
# {'colorscale': 'original',
#  'linewidth': 1.3,
#  'bargap': 0.01,
#  'layout': {'legend': {'bgcolor': '#F5F6F9', 'font': {'color': '#4D5663'}},
#   'paper_bgcolor': '#F5F6F9',
#   'plot_bgcolor': '#F5F6F9',
#   'yaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'xaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'titlefont': {'color': '#4D5663'}},
#  'annotations': {'fontcolor': '#4D5663', 'arrowcolor': '#9499A3'},
#  '3d': {'yaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'},
#   'xaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'}}}

# %%
cf.set_config_file(theme='polar')
df2.iplot(kind='scatter', x='fare', y='age', mode='markers', xTitle='fare', yTitle='age')
# Out:
# <div>                            <div id="d721f96e-c0c8-4929-b004-fbac09e3f418" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
