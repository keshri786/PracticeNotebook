# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\kesdan02\OneDrive - TMF Group\Documents\PandasPracticeFolder\AnnualReport.csv')

# %%
data
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 17023  2021                  all                     All Industries
# 17024  2021                  all                     All Industries
# 17025  2021                  all                     All Industries
# 17026  2021                  all                     All Industries
# 17027  2021                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
data.head(10)
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
# 5  2011                    A  Agriculture, Forestry and Fishing          a_0
# 6  2011                    A  Agriculture, Forestry and Fishing          a_0
# 7  2011                    A  Agriculture, Forestry and Fishing          a_0
# 8  2011                    A  Agriculture, Forestry and Fishing          a_0
# 9  2011                    A  Agriculture, Forestry and Fishing        b_1-5
#
#                                           variable  value               unit
# ...

# %%
data.tail()
# Out:
#        year industry_code_ANZSIC industry_name_ANZSIC   rme_size_grp  \
# 17023  2021                  all       All Industries  j_Grand_Total
# 17024  2021                  all       All Industries  j_Grand_Total
# 17025  2021                  all       All Industries  j_Grand_Total
# 17026  2021                  all       All Industries  j_Grand_Total
# 17027  2021                  all       All Industries  j_Grand_Total
#
#                           variable    value               unit
# 17023                 Total income   757504  DOLLARS(millions)
# 17024            Total expenditure   654404  DOLLARS(millions)
# 17025  Operating profit before tax    85116  DOLLARS(millions)
# 17026                 Total assets  2512677  DOLLARS(millions)
# 17027        Fixed tangible assets   591351  DOLLARS(millions)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.to_csv("testAnnual.csv")

# %%
pd.read_csv('testAnnual.csv')
# Out:
#        Unnamed: 0  year industry_code_ANZSIC  \
# 0               0  2011                    A
# 1               1  2011                    A
# 2               2  2011                    A
# 3               3  2011                    A
# 4               4  2011                    A
# ...           ...   ...                  ...
# 17023       17023  2021                  all
# 17024       17024  2021                  all
# 17025       17025  2021                  all
# 17026       17026  2021                  all
# 17027       17027  2021                  all
#
#                     industry_name_ANZSIC   rme_size_grp  \
# 0      Agriculture, Forestry and Fishing            a_0
# 1      Agriculture, Forestry and Fishing            a_0
# 2      Agriculture, Forestry and Fishing            a_0
# 3      Agriculture, Forestry and Fishing            a_0
# 4      Agriculture, Forestry and Fishing            a_0
# ...                                  ...            ...
# ...

# %%
data = pd.read_csv(r'C:\Users\kesdan02\OneDrive - TMF Group\Documents\PandasPracticeFolder\AnnualReport.csv', sep=',', header=None, names=['a','b','c','d','e','f','g'], na_values=['2011'])

# %%
data
# Out:
#           a                     b                                  c  \
# 0      year  industry_code_ANZSIC               industry_name_ANZSIC
# 1       NaN                     A  Agriculture, Forestry and Fishing
# 2       NaN                     A  Agriculture, Forestry and Fishing
# 3       NaN                     A  Agriculture, Forestry and Fishing
# 4       NaN                     A  Agriculture, Forestry and Fishing
# ...     ...                   ...                                ...
# 17024  2021                   all                     All Industries
# 17025  2021                   all                     All Industries
# 17026  2021                   all                     All Industries
# 17027  2021                   all                     All Industries
# 17028  2021                   all                     All Industries
#
#                    d                                                e  \
# ...

# %%
data = pd.read_csv(r'C:\Users\kesdan02\OneDrive - TMF Group\Documents\PandasPracticeFolder\AnnualReport.csv')

# %%
data
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 17023  2021                  all                     All Industries
# 17024  2021                  all                     All Industries
# 17025  2021                  all                     All Industries
# 17026  2021                  all                     All Industries
# 17027  2021                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
data.describe()
# Out:
#                year
# count  17028.000000
# mean    2016.000000
# std        3.162371
# min     2011.000000
# 25%     2013.000000
# 50%     2016.000000
# 75%     2019.000000
# max     2021.000000

# %%
data.dtypes
# Out:
# year                     int64
# industry_code_ANZSIC    object
# industry_name_ANZSIC    object
# rme_size_grp            object
# variable                object
# value                   object
# unit                    object
# dtype: object

# %%
data = pd.read_csv(r'C:\Users\kesdan02\OneDrive - TMF Group\Documents\PandasPracticeFolder\AnnualReport.csv')

# %%
data
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 17023  2021                  all                     All Industries
# 17024  2021                  all                     All Industries
# 17025  2021                  all                     All Industries
# 17026  2021                  all                     All Industries
# 17027  2021                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
data.to_csv("AnnualTest1.csv", index=False, header=False, sep="#", columns=['year','industry_code_ANZSIC'])

# %%
data.head()
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable  value               unit
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
# 4                                     Total income   8866  DOLLARS(millions)

# %%
data.columns
# Out:
# Index(['year', 'industry_code_ANZSIC', 'industry_name_ANZSIC', 'rme_size_grp',
#        'variable', 'value', 'unit'],
#       dtype='object')

# %%
data['year']
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 17023    2021
# 17024    2021
# 17025    2021
# 17026    2021
# 17027    2021
# Name: year, Length: 17028, dtype: int64

# %%
type(data['year'])
# Out:
# pandas.core.series.Series

# %%
data[['year']]
# Out:
#        year
# 0      2011
# 1      2011
# 2      2011
# 3      2011
# 4      2011
# ...     ...
# 17023  2021
# 17024  2021
# 17025  2021
# 17026  2021
# 17027  2021
#
# [17028 rows x 1 columns]

# %%
type(data[['year']])
# Out:
# pandas.core.frame.DataFrame

# %%
data[['year', 'industry_code_ANZSIC']]
# Out:
#        year industry_code_ANZSIC
# 0      2011                    A
# 1      2011                    A
# 2      2011                    A
# 3      2011                    A
# 4      2011                    A
# ...     ...                  ...
# 17023  2021                  all
# 17024  2021                  all
# 17025  2021                  all
# 17026  2021                  all
# 17027  2021                  all
#
# [17028 rows x 2 columns]

# %%
pd.read_excel(r"C:\Users\kesdan02\OneDrive - TMF Group\Documents\PandasPracticeFolder\SampleXLSFile.xls", sheet_name='Sample-spreadsheet-file')
# Out:
#         1   Eldon Base for stackable storage shelf, platinum  \
# 0       2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 1       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2       4                                               R380
# 3       5                           Holmes HEPA Air Purifier
# 4       6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# ..    ...                                                ...
# 994   996                                         Xerox 1905
# 995   997              Dana Halogen Swing-Arm Architect Lamp
# 996   998                               Maxell DVD-RAM Discs
# 997   999  DAX Contemporary Wood Frame with Silver Metal ...
# 998  1000  Computer Printout Paper with Letter-Trim Perfo...
#
#     Muhammed MacIntyre      3    -213.25   38.94     35           Nunavut  \
# 0         Barry French    293   457.8100  208.16  68.02           Nunavut
# 1         Barry French    293    46.7075    8.69   2.99           Nunavut
# ...

# %%
data1 = pd.read_html('https://www.basketball-reference.com/')

# %%
data1
# Out:
# [   East Unnamed: 1 Unnamed: 2  W  L
#  0   MIA          F          $  0  0
#  1   WAS          F          $  0  0
#  2   TOR          F          $  0  0
#  3   PHI          F          $  0  0
#  4   ORL          F          $  0  0
#  5   NYK          F          $  0  0
#  6   MIL          F          $  0  0
#  7   ATL          F          $  0  0
#  8   IND          F          $  0  0
#  9   CLE          F          $  0  0
#  10  BOS          F          $  0  0
#  11  BRK          F          $  0  0
#  12  CHI          F          $  0  0
#  13  CHO          F          $  0  0
#  14  DET          F          $  0  0,
#     West Unnamed: 1 Unnamed: 2  W  L
#  0   MEM          F          $  0  0
#  1   DEN          F          $  0  0
#  2   DAL          F          $  0  0
#  3   MIN          F          $  0  0
#  4   NOP          F          $  0  0
#  5   GSW          F          $  0  0
#  6   OKC          F          $  0  0
#  7   LAL          F          $  0  0
# ...

# %%
type(data1)
# Out:
# list

# %%
len(data1)
# Out:
# 20

# %%
data1[5]
# Out:
#          Unnamed: 0_level_0 Regular Season
#                        Team              W   L   W/L%
# 0              FC Barcelona             27   7  0.794
# 1               Real Madrid             25   9  0.735
# 2           Valencia Basket             23  11  0.676
# 3    Club Joventut Badalona             22  12  0.647
# 4           Lenovo Tenerife             21  13  0.618
# 5            Bitci Baskonia             20  14  0.588
# 6              Baxi Manresa             20  14  0.588
# 7    Herbalife Gran Canaria             17  17  0.500
# 8               UCAM Murcia             16  18  0.471
# 9       Surne Bilbao Basket             16  18  0.471
# 10              Río Breogán             16  18  0.471
# 11                  Unicaja             13  21  0.382
# 12        Coosur Real Betis             13  21  0.382
# 13      Casademont Zaragoza             12  22  0.353
# 14         Monbus Obradoiro             12  22  0.353
# 15        Urbas Fuenlabrada             12  22  0.353
# ...

# %%
data1[6].to_csv('player.csv')

# %%
s = """{
"name" : "keshri",
"phn_no" : 454545,
"comp" : ["atos","tmf", "symphony"]
}"""

# %%
import json

# %%
s1 = json.loads(s)

# %%
s1
# Out:
# {'name': 'keshri', 'phn_no': 454545, 'comp': ['atos', 'tmf', 'symphony']}

# %%
type(s1)
# Out:
# dict

# %%
pd.DataFrame(s1, columns=['comp'])
# Out:
#        comp
# 0      atos
# 1       tmf
# 2  symphony

# %%
import requests

# %%
res = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48869',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48869/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48869/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/48869/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/48869',
#   'id': 1391339169,
#   'node_id': 'PR_kwDOAA0YD84_4YaP',
#   'number': 48869,
#   'title': 'ENH: Use a proper CSS parser for pandas Styler objects',
#   'user': {'login': 'marknsikora',
#    'id': 3451892,
#    'node_id': 'MDQ6VXNlcjM0NTE4OTI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3451892?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marknsikora',
#    'html_url': 'https://github.com/marknsikora',
# ...

# %%
js = res.json()

# %%
type(js)
# Out:
# list

# %%
js[0]['title']
# Out:
# 'ENH: Use a proper CSS parser for pandas Styler objects'

# %%
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# ENH: Use a proper CSS parser for pandas Styler objects
# ENH: Use a proper CSS parser for pandas Styler objects
# BUG/API: setting behavior inserting negative numbers in np.uint/nullable UInt Series
# REGR: replace replacing wrong values with inplace and datetime
# ENH: retain reso in Timestamp(dt64_obj)
# API: what should float(pd.NA) return?
# BUG: pd.fillna(np.nan, inplace=True) replaces values which are not None when using datetime dtype
# REF: helpers to de-duplicate datetimelike arithmetic
# STYLE: Add code check to avoid returning Exceptions instead of raising
# BUG: Bar chart is not consistent in its color management when plotting Series or single column DataFrame
# BUG: convert_dtypes not converting with pd.NA and object dtype
# STYLE fix pylint issues
# BUG: to_timedelta raising for ea float
# REGR: Avoid unnecessary warning when setting empty dataframe
# TYP: Numpy 1.23 typing issues
# DEP: Enforce deprecations of read_csv keywords
# ...

# %%
pd.DataFrame(js)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
pd.DataFrame(js, columns=['url', 'title', 'user'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js1 =pd.DataFrame(js, columns=['user'])

# %%
js1
# Out:
#                                                  user
# 0   {'login': 'marknsikora', 'id': 3451892, 'node_...
# 1   {'login': 'marknsikora', 'id': 3451892, 'node_...
# 2   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 3   {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 4   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 5   {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 6   {'login': 'adnapPanda', 'id': 47595365, 'node_...
# 7   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 8   {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 9   {'login': 'jlandercy', 'id': 20479241, 'node_i...
# 10  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 11  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 12  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 13  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 14  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 15  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# ...

# %%
listData = []
for i in range(len(js)):
    listData.append(js[i]['user'])

# %%
pd.DataFrame(listData)
# Out:
#            login        id               node_id  \
# 0    marknsikora   3451892  MDQ6VXNlcjM0NTE4OTI=
# 1    marknsikora   3451892  MDQ6VXNlcjM0NTE4OTI=
# 2      mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 3          phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 4   jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 5   MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 6     adnapPanda  47595365  MDQ6VXNlcjQ3NTk1MzY1
# 7   jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 8          phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 9      jlandercy  20479241  MDQ6VXNlcjIwNDc5MjQx
# 10         phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 11  MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 12         phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 13         phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 14         phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 15         phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 16       itholic  44108233  MDQ6VXNlcjQ0MTA4MjMz
# 17         phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# ...

# %%
json_data = pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
pd.DataFrame.from_records(json_data['user'])
# Out:
#            login        id               node_id  \
# 0    marknsikora   3451892  MDQ6VXNlcjM0NTE4OTI=
# 1    marknsikora   3451892  MDQ6VXNlcjM0NTE4OTI=
# 2      mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 3          phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 4   jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 5   MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 6     adnapPanda  47595365  MDQ6VXNlcjQ3NTk1MzY1
# 7   jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 8          phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 9      jlandercy  20479241  MDQ6VXNlcjIwNDc5MjQx
# 10         phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 11  MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 12         phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 13         phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 14         phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 15         phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 16       itholic  44108233  MDQ6VXNlcjQ0MTA4MjMz
# 17         phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# ...
